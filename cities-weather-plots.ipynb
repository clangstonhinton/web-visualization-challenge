# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from pprint import pprint
from scipy import stats
from colorspacious import cspace_converter

# %% [markdown]
# ### Read in CSV file

# %%
# Read csv file into pandas dataframe
city_data = pd.read_csv ('Resources/cities.csv')

# Display sample data
city_data.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %% [markdown]
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

x = city_data["Lat"]
y = city_data["Max Temp"]

plt.scatter(x, y, c=y, cmap="turbo")

# Incorporate the other graph properties

plt.title("Latitude vs Max Temperature of Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.colorbar()
plt.grid()

# Save the figure
plt.savefig("assets/images/lat_vs_temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

x = city_data["Lat"]
y = city_data["Humidity"]

plt.scatter(x, y, c=y, cmap="turbo")

# Incorporate the other graph properties

plt.title("Latitude vs Humidity of Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.colorbar()
plt.grid()

# Save the figure
plt.savefig("assets/images/lat_vs_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness

x = city_data["Lat"]
y = city_data["Cloudiness"]

plt.scatter(x, y, c=y, cmap="turbo")

# Incorporate the other graph properties

plt.title("Latitude vs Cloudiness of Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.colorbar()
plt.grid()

# Save the figure
plt.savefig("assets/images/lat_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

x = city_data["Lat"]
y = city_data["Wind Speed"]

plt.scatter(x, y, c=y, cmap="turbo")

# Incorporate the other graph properties

plt.title("Latitude vs Wind Speed of Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.colorbar()
plt.grid()

# Save the figure
plt.savefig("assets/images/lat_vs_wind.png")

# Show plot
plt.show()
