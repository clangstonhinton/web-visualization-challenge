# %%
import pandas as pd

# %%
city_table = pd.read_csv ('Resources/cities.csv')

# Display sample data
city_table.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
    <thead>
      <tr>
        <th colspan="9">City Weather Data2</th>
      </tr>
      <tr>
        <th>City</th>
        <th>Country</th>
        <th>Lat</th>
        <th>Lng</th>
        <th>Date</th>
        <th>Max Temp</th>
        <th>Humidity>
        <th>Cloudiness</th>
        <th>Wind Speed</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>jacareacanga</td>
        <td>BR</td>
        <td>-6.22</td>
        <td>-57.76</td>
        <td>1528902000</td>
        <td>89.60</td>
        <td>62</td>
        <td>0</td>
        <td>6.93</td>
      </tr>
# Out:
# 9

# %%
temp_header = list(all_df[2].columns)

# %%
all_df[2]
# Out:
#    Rank          Player               Years League[24] FA Cup[25]  \
# 0     1    Wayne Rooney           2004–2017  183 (393)  022 0(40)
# 1     2  Bobby Charlton           1956–1973  199 (606)  019 0(78)
# 2     3       Denis Law           1962–1973  171 (309)  034 0(46)
# 3     4     Jack Rowley           1937–1955  182 (380)  026 0(42)
# 4     5  Dennis Viollet           1952–1962  159 (259)  005 0(18)
# 5     5     George Best           1963–1974  137 (361)  021 0(46)
# 6     7      Joe Spence           1919–1933  158 (481)  010 0(29)
# 7     7      Ryan Giggs           1991–2014  114 (672)  012 0(74)
# 8     9     Mark Hughes  1983–19861988–1995  120 (345)  017 0(46)
# 9    10    Paul Scholes  1994–20112012–2013  107 (499)  013 0(49)
#
#   League Cup[26] Europe[27] Other[C][28]  Total[29]  Goalsper game
# 0      005 0(20)  039 0(98)    004 00(8)  253 (559)           0.45
# 1      007 0(24)  022 0(45)    002 00(5)  249 (758)           0.33
# ...

# %%
print("<th>")
for c in temp_header:
    print("<th>{}</th>".format(c))
print("</th>")
# Out:
# <th>
# <th>Rank</th>
# <th>Player</th>
# <th>Years</th>
# <th>League[24]</th>
# <th>FA Cup[25]</th>
# <th>League Cup[26]</th>
# <th>Europe[27]</th>
# <th>Other[C][28]</th>
# <th>Total[29]</th>
# <th>Goalsper game</th>
# </th>

# %%
for r in all_df[2].iterrows():
    print("<tr>",end='')
    print("<td>{}</td>".format(r[1]["Rank"]),end='')
    print("<td>{}</td>".format(r[1]["Player"]),end='')
    print("<td>{}</td>".format(r[1]["Years"]),end='')
    print("<td>{}</td>".format(r[1]["League[24]"]),end='')
    print("<td>{}</td>".format(r[1]["FA Cup[25]"]),end='')
    print("<td>{}</td>".format(r[1]["League Cup[26]"]),end='')
    print("<td>{}</td>".format(r[1]["Europe[27]"]),end='')
    print("<td>{}</td>".format(r[1]["Other[C][28]"]),end='')
    print("<td>{}</td>".format(r[1]["Total[29]"]),end='')
    print("<td>{}</td>".format(r[1]["Goalsper game"]),end='')
    print("</tr>")
# Out:
# <tr><td>1</td><td>Wayne Rooney</td><td>2004–2017</td><td>183 (393)</td><td>022 0(40)</td><td>005 0(20)</td><td>039 0(98)</td><td>004 00(8)</td><td>253 (559)</td><td>0.45</td></tr>
# <tr><td>2</td><td>Bobby Charlton</td><td>1956–1973</td><td>199 (606)</td><td>019 0(78)</td><td>007 0(24)</td><td>022 0(45)</td><td>002 00(5)</td><td>249 (758)</td><td>0.33</td></tr>
# <tr><td>3</td><td>Denis Law</td><td>1962–1973</td><td>171 (309)</td><td>034 0(46)</td><td>003 0(11)</td><td>028 0(33)</td><td>001 00(5)</td><td>237 (404)</td><td>0.59</td></tr>
# <tr><td>4</td><td>Jack Rowley</td><td>1937–1955</td><td>182 (380)</td><td>026 0(42)</td><td>000 00(0)</td><td>000 00(0)</td><td>003 00(2)</td><td>211 (424)</td><td>0.5</td></tr>
# <tr><td>5</td><td>Dennis Viollet</td><td>1952–1962</td><td>159 (259)</td><td>005 0(18)</td><td>001 00(2)</td><td>013 0(12)</td><td>001 00(2)</td><td>179 (293)</td><td>0.61</td></tr>
# ...
